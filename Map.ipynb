# %%
import pandas as pd

# Load Excel file
df = pd.read_excel("Cleaned_Resource_PWC.xlsx")

# Convert to dictionary format for easier use in Flask
#resources = df.to_dict(orient="records")

# Example output:
#resources

# %%
df.head()
# Out:
#   VERIFICATION STATUS                                    ORGANIZATION  \
# 0            Verified                            Abundant Life Church
# 1            Verified                   Abundant Life Ministries Inc.
# 2            Verified  ACTS Beverly Warren Emergency Homeless Shelter
# 3            Verified                  ACTS Domestic Violence Support
# 4            Verified                             ACTS Food Assitance
#
#                       CATEGORY  \
# 0         Faith Based Services
# 1  Faith Based Services (Food)
# 2   Housing Utilities Finances
# 3                       Family
# 4                         Food
#
#                                               EMAIL   \
# 0                                                NaN
# 1  DrEllis@abundant-lifeministries.com/MinisterSo...
# 2                                   info@actspwc.org
# 3                                   info@actspwc.org
# 4                                   info@actspwc.org
#
#                              PHONE                                ADDRESS  \
# 0  (703)364-9580 or (703) 364-9580  12964 Harbor Dr, Woodbridge, VA 22192
# 1                              NaN     PO Box 1878, Woodbridge, VA  22195
# 2                     703-221-3188  17866 Main Street, Dumfries, VA 22026
# 3                   (703) 221-4951     3900 ACTS lane, Dumfries, VA 22026
# 4                   (703) 441-8606     3900 ACTS Lane, Dumfries, VA 22026
#
#                                             WEBSITE  \
# 0                             www.woodbridge.church
# 1                   www.abundant-lifeministries.com
# 2           https://actspwc.org/housing-assistance/
# 3            https://actspwc.org/domestic-violence/
# 4  https://www.actspwc.org/services/food-assistance
#
#                                    Services Provided  \
# 0  The mission of the church is to reach the whol...
# 1  A.L.M. Inc. is Called to Cultivate Community t...
# 2  The ACTS Beverly Warren Emergency Homeless She...
# 3  ACTS DOMESTIC VIOLENCE SERVICES’ (TURNING POIN...
# 4  ACTS' food pantry provides food assistance to ...
#
#                                     Hours of Service  \
# 0  Sunday Morning\n10:00am\nWednesday Evenings\n7...
# 1                                                NaN
# 2  Available 24/7 Yes\nAdditional Availability Co...
# 3                                                NaN
# 4  Main Location:\nSunday: Closed\nMonday: 8:00 A...
#
#                                              Comment
# 0                                                NaN
# 1                                                NaN
# 2  Intake Process Appointment is required. Call 7...
# 3  Domestic Violence Hotline 24/7 support (703) 2...
# 4  Languages: English, Spanish\nDocuments Require...

# %%
df1 = df[df['VERIFICATION STATUS'] == 'Verified']
df1.head()
# Out:
#   VERIFICATION STATUS                                    ORGANIZATION  \
# 0            Verified                            Abundant Life Church
# 1            Verified                   Abundant Life Ministries Inc.
# 2            Verified  ACTS Beverly Warren Emergency Homeless Shelter
# 3            Verified                  ACTS Domestic Violence Support
# 4            Verified                             ACTS Food Assitance
#
#                       CATEGORY  \
# 0         Faith Based Services
# 1  Faith Based Services (Food)
# 2   Housing Utilities Finances
# 3                       Family
# 4                         Food
#
#                                               EMAIL   \
# 0                                                NaN
# 1  DrEllis@abundant-lifeministries.com/MinisterSo...
# 2                                   info@actspwc.org
# 3                                   info@actspwc.org
# 4                                   info@actspwc.org
#
#                              PHONE                                ADDRESS  \
# 0  (703)364-9580 or (703) 364-9580  12964 Harbor Dr, Woodbridge, VA 22192
# 1                              NaN     PO Box 1878, Woodbridge, VA  22195
# 2                     703-221-3188  17866 Main Street, Dumfries, VA 22026
# 3                   (703) 221-4951     3900 ACTS lane, Dumfries, VA 22026
# 4                   (703) 441-8606     3900 ACTS Lane, Dumfries, VA 22026
#
#                                             WEBSITE  \
# 0                             www.woodbridge.church
# 1                   www.abundant-lifeministries.com
# 2           https://actspwc.org/housing-assistance/
# 3            https://actspwc.org/domestic-violence/
# 4  https://www.actspwc.org/services/food-assistance
#
#                                    Services Provided  \
# 0  The mission of the church is to reach the whol...
# 1  A.L.M. Inc. is Called to Cultivate Community t...
# 2  The ACTS Beverly Warren Emergency Homeless She...
# 3  ACTS DOMESTIC VIOLENCE SERVICES’ (TURNING POIN...
# 4  ACTS' food pantry provides food assistance to ...
#
#                                     Hours of Service  \
# 0  Sunday Morning\n10:00am\nWednesday Evenings\n7...
# 1                                                NaN
# 2  Available 24/7 Yes\nAdditional Availability Co...
# 3                                                NaN
# 4  Main Location:\nSunday: Closed\nMonday: 8:00 A...
#
#                                              Comment
# 0                                                NaN
# 1                                                NaN
# 2  Intake Process Appointment is required. Call 7...
# 3  Domestic Violence Hotline 24/7 support (703) 2...
# 4  Languages: English, Spanish\nDocuments Require...

# %%
df2 = df1[~df1.CATEGORY.isin(['Faith Based Services (Food)','Faith Based Services','Faith Based Services (Blood Services)','Faith Based Services (parenting)'])]

# %%
df3 = df2[~pd.isna(df2.ADDRESS)]

# %%
df3.shape
# Out:
# (180, 10)

# %%
df3.CATEGORY.value_counts()
# Out:
# Family                              38
# Housing Utilities Finances          30
# Community and Recreation Centers    21
# Education Services                  19
# Food                                16
# Immigrant Support Services          10
# Medical and Healthcare               8
# Employment Services                  7
# Clothing                             6
# Parenting                            4
# Veteran Services                     4
# Mental Health Substance Use          3
# Hotlines Crisis                      3
# Pet                                  2
# Real Estate                          2
# Environmental Services               1
# Voting Services                      1
# LGBTQ                                1
# Language                             1
# Legal Services                       1
# Detention Services                   1
# Business Services                    1
# Name: CATEGORY, dtype: int64

# %%
# Use Google Map API to generate each address' latitude and longitude according to the complete address name

import googlemaps

# Initialize the Google Maps client with your API key
gmaps = googlemaps.Client(key='AIzaSyD1CdlrFtxX_oR4c6rnSW_JM7PZL_bxvTk')

# create empty lists to store latitudes and longitudes
latitudes = []
longitudes = []

# iterate over each row in the dataframe
for index, row in df3.iterrows():
    # concatenate the address components
    address = f"{row['ADDRESS']}, United States"
    # use geocoding API to get location information
    geocode_result = gmaps.geocode(address)
    # if location information is found, append the latitude and longitude to the lists
    if geocode_result:
        location = geocode_result[0]['geometry']['location']
        latitudes.append(location['lat'])
        longitudes.append(location['lng'])
    # if location information is not found, append None to the lists
    else:
        latitudes.append(None)
        longitudes.append(None)

# add the latitude and longitude columns to the dataframe
df3['latitude'] = latitudes
df3['longitude'] = longitudes
# Out:
# /var/folders/39/p0rpjrxj68l4cbrkhyvw78fm0000gn/T/ipykernel_35539/353140845.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['latitude'] = latitudes
# /var/folders/39/p0rpjrxj68l4cbrkhyvw78fm0000gn/T/ipykernel_35539/353140845.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['longitude'] = longitudes

# %%
df3.isna().sum()
# Out:
# VERIFICATION STATUS      0
# ORGANIZATION             0
# CATEGORY                 0
# EMAIL                   68
# PHONE                   12
# ADDRESS                  0
# WEBSITE                  1
# Services Provided       19
# Hours of Service        97
# Comment                149
# latitude                 0
# longitude                0
# dtype: int64

# %%
df3.to_csv('DataSet.csv',index=False)

# %%
import folium
import pandas as pd
from folium.plugins import MarkerCluster

# %%
df3.CATEGORY.value_counts()
# Out:
# Family                              38
# Housing Utilities Finances          30
# Community and Recreation Centers    21
# Education Services                  19
# Food                                16
# Immigrant Support Services          10
# Medical and Healthcare               8
# Employment Services                  7
# Clothing                             6
# Parenting                            4
# Veteran Services                     4
# Mental Health Substance Use          3
# Hotlines Crisis                      3
# Pet                                  2
# Real Estate                          2
# Environmental Services               1
# Voting Services                      1
# LGBTQ                                1
# Language                             1
# Legal Services                       1
# Detention Services                   1
# Business Services                    1
# Name: CATEGORY, dtype: int64

# %%
df3.columns
# Out:
# Index(['VERIFICATION STATUS', 'ORGANIZATION', 'CATEGORY', 'EMAIL ', 'PHONE',
#        'ADDRESS', 'WEBSITE', 'Services Provided', 'Hours of Service',
#        'Comment', 'latitude', 'longitude'],
#       dtype='object')

# %%
resources = df3.to_dict(orient="records")

# Define custom icons for different resource types
ICON_MAP = {
    "Family": ("users", "purple"),
    "Housing Utilities Finances": ("home", "blue"),
    "Community and Recreation Centers": ("users", "teal"),
    "Education Services": ("graduation-cap", "darkblue"),
    "Food": ("cutlery", "orange"),
    "Immigrant Support Services": ("globe", "darkgreen"),
    "Medical and Healthcare": ("medkit", "red"),
    "Employment Services": ("briefcase", "darkblue"),
    "Clothing": ("shopping-bag", "brown"),
    "Parenting": ("child", "green"),
    "Veteran Services": ("star", "darkgreen"),
    "Mental Health Substance Use": ("heartbeat", "pink"),
    "Hotlines Crisis": ("phone", "darkred"),
    "Pet": ("paw", "darkorange"),
    "Real Estate": ("building", "gray"),
    "Environmental Services": ("leaf", "green"),
    "Voting Services": ("check-square", "black"),
    "LGBTQ": ("rainbow", "purple"),
    "Language": ("language", "darkblue"),
    "Legal Services": ("balance-scale", "black"),
    "Detention Services": ("gavel", "darkred"),
    "Business Services": ("handshake", "gold"),
}


# Create map centered around the county
m = folium.Map(location=[38.7, -77.3], zoom_start=10)

marker_cluster = MarkerCluster().add_to(m)

# Add markers for each resource
for res in resources:
    # Get icon name and color based on type
    icon_symbol, icon_color = ICON_MAP.get(res["CATEGORY"], ("info-circle", "gray"))

    # Ensure website is a string and handle None values
    website_link = f'<a href="{res["WEBSITE"]}" target="_blank">Visit</a>' if isinstance(res["WEBSITE"], str) and res["WEBSITE"] else "N/A"

    # Format popup content with styled HTML
    popup_content = f"""
    <div style="font-family: Arial; font-size: 13px;">
        <b style="font-size: 14px;">{res['ORGANIZATION']}</b><br>
        <i style="color: #555;">{res['CATEGORY']}</i><br><br>
        <b>Services Provided:</b> {res['Services Provided']}<br>
        <b>Hours of Service:</b> {res['Hours of Service']}<br>
        <b>Address:</b> {res['ADDRESS']}<br>
        <b>Email:</b> {res['EMAIL '] if res['EMAIL '] else 'N/A'}<br>
        <b>Phone:</b> {res['PHONE'] if res['PHONE'] else 'N/A'}<br>
        <b>Website:</b> {website_link}
    </div>
    """

    # Create the marker with the correct icon and color
    folium.Marker(
        location=[res["latitude"], res["longitude"]],
        popup=folium.Popup(popup_content, max_width=300),
        icon=folium.Icon(color=icon_color, icon=icon_symbol, prefix="fa")
    ).add_to(marker_cluster)

m
# Out:
# /var/folders/39/p0rpjrxj68l4cbrkhyvw78fm0000gn/T/ipykernel_35539/1994515535.py:61: UserWarning: color argument of Icon should be one of: {'lightred', 'darkgreen', 'gray', 'orange', 'blue', 'cadetblue', 'lightgreen', 'purple', 'darkred', 'darkpurple', 'lightgray', 'darkblue', 'pink', 'beige', 'black', 'white', 'green', 'lightblue', 'red'}.
#   icon=folium.Icon(color=icon_color, icon=icon_symbol, prefix="fa")
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cd6c5a968076394214b320737168668 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cd6c5a968076394214b320737168668&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cd6c5a968076394214b320737168668 = L.map(
#                 &quot;map_1cd6c5a968076394214b320737168668&quot;,
#                 {
#                     center: [38.7, -77.3],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75acfbe7dfd6ac9957b314b299941e51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_75acfbe7dfd6ac9957b314b299941e51.addTo(map_1cd6c5a968076394214b320737168668);
#
#
#             var marker_cluster_941e5105fa178dc28c8cf5316b14622c = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_931076020ef42439695ce18434faf920 = L.marker(
#                 [38.5649964, -77.3299755],
#                 {}
#             ).addTo(marker_cluster_941e5105fa178dc28c8cf5316b14622c);
#
#
#             var icon_aa3773e5cc58438001474a54fd3d255d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_931076020ef42439695ce18434faf920.setIcon(icon_aa3773e5cc58438001474a54fd3d255d);
#
#
#         var popup_04179a04fe236572ca44ae063ed19a92 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_111e0ec16b29a3a22b879fee99d547cb = $(`&lt;div id=&quot;html_111e0ec16b29a3a22b879fee99d547cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&quot;font-family: Arial; font-size: 13px;&quot;&gt;         &lt;b style=&quot;font-size: 14px;&quot;&gt;ACTS Beverly Warren Emergency Homeless Shelter&lt;/b&gt;&lt;br&gt;         &lt;i style=&quot;color: #555;&quot;&gt;Housing Utilities Finances&lt;/i&gt;&lt;br&gt;&lt;br&gt;         &lt;b&gt;Services Provided:&lt;/b&gt; The ACTS Beverly Warren Emergency Homeless Shelter provides emergency short-term housing to families and singles. Serves up to 18. Room and board are free; the shelter is open 24 hours a day for single females or families with children. Services include intensive case management, life skills training, and computer access for job and housing search. The ultimate goal of our program is the clients’ self-sufficiency.  If you are  - Homeless - Facing eviction - Living on the street - Living in an unsuitable for human habitation facility Case managers offer guidance in applying for assistance to become self-sufficient, find permanent housing, and limited employment services, including Social Security and SNAP.  &lt;br&gt;         &lt;b&gt;Hours of Service:&lt;/b&gt; Available 24/7 Yes Additional Availability Comments Assistance hours Mondays and Thursdays 9 - 11:30 am and 1 - 3 pm; Tuesdays 1 - 3:30 pm and 5 - 6:30 pm.&lt;br&gt;         &lt;b&gt;Address:&lt;/b&gt; 17866 Main Street, Dumfries, VA 22026&lt;br&gt;         &lt;b&gt;Email:&lt;/b&gt; info@actspwc.org&lt;br&gt;         &lt;b&gt;Phone:&lt;/b&gt; 703-221-3188&lt;br&gt;         &lt;b&gt;Website:&lt;/b&gt; &lt;a href=&quot;https://actspwc.org/housing-assistance/&quot; target=&quot;_blank&quot;&gt;Visit&lt;/a&gt;     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_04179a04fe236572ca44ae063ed19a92.setContent(html_111e0ec16b29a3a22b879fee99d547cb);
#
#
#
#         marker_931076020ef42439695ce18434faf920.bindPopup(popup_04179a04fe236572ca44ae063ed19a92)
#         ;
#
#
#
#
#             var marker_5b048527d78aa185a7e7904eebe767e0 = L.marker(
#                 [38.5631747, -77.3290854],
#                 {}
#             ).addTo(marker_cluster_941e5105fa178dc28c8cf5316b14622c);
#
#
#             var icon_406ff35394eca6b57b75ba47296f630a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;users&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5b048527d78aa185a7e7904eebe767e0.setIcon(icon_406ff35394eca6b57b75ba47296f630a);
#
#
#         var popup_5694dfba52418f75fe5c37eedf71559f = L.popup({&quot;max

# %%
df3.head()
# Out:
#   VERIFICATION STATUS                                    ORGANIZATION  \
# 2            Verified  ACTS Beverly Warren Emergency Homeless Shelter
# 3            Verified                  ACTS Domestic Violence Support
# 4            Verified                             ACTS Food Assitance
# 6            Verified                               ACTS Thrfit Store
# 7            Verified          Adams Compassionate Healthcare Network
#
#                      CATEGORY                  EMAIL            PHONE  \
# 2  Housing Utilities Finances        info@actspwc.org    703-221-3188
# 3                      Family        info@actspwc.org  (703) 221-4951
# 4                        Food        info@actspwc.org  (703) 441-8606
# 6                    Clothing      cwillut@actspwc.us  (703) 221-3298
# 7      Medical and Healthcare  contact@achnhealth.org  (703) 542-3366
#
#                                              ADDRESS  \
# 2              17866 Main Street, Dumfries, VA 22026
# 3                 3900 ACTS lane, Dumfries, VA 22026
# 4                 3900 ACTS Lane, Dumfries, VA 22026
# 6                3661 Canal Road, Dumfries, VA 22026
# 7  4431 Brookfield Corporate Drive, Unit F Chanti...
#
#                                             WEBSITE  \
# 2           https://actspwc.org/housing-assistance/
# 3            https://actspwc.org/domestic-violence/
# 4  https://www.actspwc.org/services/food-assistance
# 6              https://www.actspwc.org/thrift-store
# 7                           https://achnhealth.org/
#
#                                    Services Provided  \
# 2  The ACTS Beverly Warren Emergency Homeless She...
# 3  ACTS DOMESTIC VIOLENCE SERVICES’ (TURNING POIN...
# 4  ACTS' food pantry provides food assistance to ...
# 6  ACTS Family Assistance sells good used clothin...
# 7  Founded in 2013, ACHN is dedicated to providin...
#
#                                     Hours of Service  \
# 2  Available 24/7 Yes\nAdditional Availability Co...
# 3                                                NaN
# 4  Main Location:\nSunday: Closed\nMonday: 8:00 A...
# 6  Monday - 10am-5pm\nTuesday, Wednesday Thursday...
# 7  Clinic Hours\nMonday – 9:00am-3:00pm\nTuesday ...
#
#                                              Comment   latitude  longitude
# 2  Intake Process Appointment is required. Call 7...  38.564996 -77.329976
# 3  Domestic Violence Hotline 24/7 support (703) 2...  38.563175 -77.329085
# 4  Languages: English, Spanish\nDocuments Require...  38.563175 -77.329085
# 6  Intake Process Walk-in\nDocuments Required Pic...  38.568720 -77.322167
# 7                                                NaN  38.885364 -77.437709

# %%
df1 = df[(~pd.isna(df['Name of Org'])&(~pd.isna(df['Address'])))].reset_index(drop=True)
df1.head()
# Out:
#                         Name of Org  Type  \
# 0               ACTS Food Assitance  Food
# 1     Creating Foundations for Hope  Food
# 2    Haymarket Regional Food Pantry  Food
# 3  Northern Virginia Family Service  Food
# 4             Serve Food Assistance  Food
#
#                                    Services Provided Hours of Service  \
# 0  Monthly food pick-up on walk-in basis. New cli...              NaN
# 1      Food distributed at East End Mobile Home Park              NaN
# 2  Weekly food pick-up (3-4 meals) for registered...              NaN
# 3  Emergency food assistance, nutrition informati...              NaN
# 4  Tuesday and Thursday intakes, appointment and ...              NaN
#
#               Email                             Phone  \
# 0  info@actspwc.org                    (703) 441-8606
# 1    info@cfhva.org          (703) 221-4510, ext 2001
# 2               NaN  (703) 754-5990, appointment only
# 3               NaN                    (571) 748-2680
# 4  ncannon@nvfs.org                    (571) 748-2680
#
#                                        Address Service Areas  \
# 0             3901 ACTS Ln, Dumfries, VA 22026           NaN
# 1           8565 Sudley Rd, Manassas, VA 20110           NaN
# 2  7669 Limestone Drive, #105, Gainesville, VA           NaN
# 3         10058 Dean Drive, Manassas, VA 20110           NaN
# 4            10056 Dean Dr, Manassas, VA 20110           NaN
#
#                                              Website Contact Person  \
# 0   https://www.actspwc.org/services/food-assistance            NaN
# 1                                 https://cfhva.org/            NaN
# 2                   https://haymarketfoodpantry.org/            NaN
# 3  https://www.nvfs.org/our-services/health-well-...            NaN
# 4  https://www.nvfs.org/our-services/homelessness...            NaN
#
#    Services Confirmed (Yes/No)  Date Contacted  Person Contacted  \
# 0                          NaN             NaN               NaN
# 1                          NaN             NaN               NaN
# 2                          NaN             NaN               NaN
# 3                          NaN             NaN               NaN
# 4                          NaN             NaN               NaN
#
#   Source of Information
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
df1.shape
# Out:
# (81, 14)

# %%
# Use Google Map API to generate each address' latitude and longitude according to the complete address name

import googlemaps

# Initialize the Google Maps client with your API key
gmaps = googlemaps.Client(key='AIzaSyD1CdlrFtxX_oR4c6rnSW_JM7PZL_bxvTk')

# create empty lists to store latitudes and longitudes
latitudes = []
longitudes = []

# iterate over each row in the dataframe
for index, row in df1.iterrows():
    # concatenate the address components
    address = f"{row['Address']}, United States"
    # use geocoding API to get location information
    geocode_result = gmaps.geocode(address)
    # if location information is found, append the latitude and longitude to the lists
    if geocode_result:
        location = geocode_result[0]['geometry']['location']
        latitudes.append(location['lat'])
        longitudes.append(location['lng'])
    # if location information is not found, append None to the lists
    else:
        latitudes.append(None)
        longitudes.append(None)

# add the latitude and longitude columns to the dataframe
df1['latitude'] = latitudes
df1['longitude'] = longitudes

# %%
df1.isna().sum()
# Out:
# Name of Org                     0
# Type                            0
# Services Provided              10
# Hours of Service               72
# Email                          54
# Phone                          13
# Address                         0
# Service Areas                  74
# Website                        18
# Contact Person                 81
# Services Confirmed (Yes/No)    81
# Date Contacted                 81
# Person Contacted               81
# Source of Information          79
# latitude                        0
# longitude                       0
# dtype: int64

# %%
df2 = df1[['Name of Org','Type','Services Provided','Email','Phone','Address','Website','latitude','longitude']]
df2.head()
# Out:
#                         Name of Org  Type  \
# 0               ACTS Food Assitance  Food
# 1     Creating Foundations for Hope  Food
# 2    Haymarket Regional Food Pantry  Food
# 3  Northern Virginia Family Service  Food
# 4             Serve Food Assistance  Food
#
#                                    Services Provided             Email  \
# 0  Monthly food pick-up on walk-in basis. New cli...  info@actspwc.org
# 1      Food distributed at East End Mobile Home Park    info@cfhva.org
# 2  Weekly food pick-up (3-4 meals) for registered...               NaN
# 3  Emergency food assistance, nutrition informati...               NaN
# 4  Tuesday and Thursday intakes, appointment and ...  ncannon@nvfs.org
#
#                               Phone  \
# 0                    (703) 441-8606
# 1          (703) 221-4510, ext 2001
# 2  (703) 754-5990, appointment only
# 3                    (571) 748-2680
# 4                    (571) 748-2680
#
#                                        Address  \
# 0             3901 ACTS Ln, Dumfries, VA 22026
# 1           8565 Sudley Rd, Manassas, VA 20110
# 2  7669 Limestone Drive, #105, Gainesville, VA
# 3         10058 Dean Drive, Manassas, VA 20110
# 4            10056 Dean Dr, Manassas, VA 20110
#
#                                              Website   latitude  longitude
# 0   https://www.actspwc.org/services/food-assistance  38.563224 -77.329121
# 1                                 https://cfhva.org/  38.770102 -77.490676
# 2                   https://haymarketfoodpantry.org/  38.790636 -77.598031
# 3  https://www.nvfs.org/our-services/health-well-...  38.744580 -77.500712
# 4  https://www.nvfs.org/our-services/homelessness...  38.744802 -77.499861

# %%
df2.Type.value_counts()
# Out:
# Family                         19
# Food                           18
# Housing Utilities Finances     15
# Medical and Healthcare         10
# Criminal Justice                7
# Mental Health Substance Use     7
# Clothing                        2
# Veteran Services                1
# Parenting                       1
# Hotlines Crisis                 1
# Name: Type, dtype: int64

# %%
# Convert to dictionary format for easier use in Flask
resources = df2.to_dict(orient="records")

# %%
import folium
import pandas as pd
from folium.plugins import MarkerCluster

# %%
df2 = pd.read_csv('Existing_withlatlong.csv')
resources = df2.to_dict(orient="records")

# Define custom icons for different resource types
ICON_MAP = {
    "Family": ("users", "purple"),
    "Food": ("cutlery", "orange"),
    "Housing Utilities Finances": ("home", "blue"),
    "Medical and Healthcare": ("medkit", "red"),
    "Criminal Justice": ("balance-scale", "black"),
    "Mental Health Substance Use": ("heartbeat", "pink"),
    "Clothing": ("shopping-bag", "brown"),
    "Veteran Services": ("star", "darkgreen"),
    "Parenting": ("child", "green"),
    "Hotlines Crisis": ("phone", "darkred"),
}

# Create map centered around the county
m = folium.Map(location=[38.5, -77.5], zoom_start=10)

marker_cluster = MarkerCluster().add_to(m)

# Add markers for each resource
for res in resources:
    # Get icon name and color based on type
    icon_symbol, icon_color = ICON_MAP.get(res["Type"], ("info-circle", "gray"))

    # Ensure website is a string and handle None values
    website_link = f'<a href="{res["Website"]}" target="_blank">Visit</a>' if isinstance(res["Website"], str) and res["Website"] else "N/A"

    # Format popup content with styled HTML
    popup_content = f"""
    <div style="font-family: Arial; font-size: 13px;">
        <b style="font-size: 14px;">{res['Name of Org']}</b><br>
        <i style="color: #555;">{res['Type']}</i><br><br>
        <b>Services Provided:</b> {res['Services Provided']}<br>
        <b>Address:</b> {res['Address']}<br>
        <b>Email:</b> {res['Email'] if res['Email'] else 'N/A'}<br>
        <b>Phone:</b> {res['Phone'] if res['Phone'] else 'N/A'}<br>
        <b>Website:</b> {website_link}
    </div>
    """

    # Create the marker with the correct icon and color
    folium.Marker(
        location=[res["latitude"], res["longitude"]],
        popup=folium.Popup(popup_content, max_width=300),
        icon=folium.Icon(color=icon_color, icon=icon_symbol, prefix="fa")
    ).add_to(marker_cluster)

m


# Save the map to an HTML file
#m.save("templates/map.html")
# Out:
# /var/folders/39/p0rpjrxj68l4cbrkhyvw78fm0000gn/T/ipykernel_24899/1592507365.py:48: UserWarning: color argument of Icon should be one of: {'beige', 'red', 'darkpurple', 'darkred', 'white', 'lightgray', 'pink', 'lightred', 'black', 'gray', 'lightblue', 'orange', 'cadetblue', 'blue', 'darkgreen', 'purple', 'green', 'lightgreen', 'darkblue'}.
#   icon=folium.Icon(color=icon_color, icon=icon_symbol, prefix="fa")
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a9dcabb0efed38f5725633e12686884 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a9dcabb0efed38f5725633e12686884&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a9dcabb0efed38f5725633e12686884 = L.map(
#                 &quot;map_9a9dcabb0efed38f5725633e12686884&quot;,
#                 {
#                     center: [38.5, -77.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_025302d66c464c43fa3e5d6850624751 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_025302d66c464c43fa3e5d6850624751.addTo(map_9a9dcabb0efed38f5725633e12686884);
#
#
#             var marker_cluster_72b128883751dff62d45e841b9243f9a = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_7f4352d1a52c3743103dd81c8554c6ef = L.marker(
#                 [38.5632239, -77.3291212],
#                 {}
#             ).addTo(marker_cluster_72b128883751dff62d45e841b9243f9a);
#
#
#             var icon_644d25973b35bd63c21de22bc480e703 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7f4352d1a52c3743103dd81c8554c6ef.setIcon(icon_644d25973b35bd63c21de22bc480e703);
#
#
#         var popup_6a70f434041f15083ac9923ab3a00205 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_150d6f0ae28991ff3d17eaf42948ade5 = $(`&lt;div id=&quot;html_150d6f0ae28991ff3d17eaf42948ade5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&quot;font-family: Arial; font-size: 13px;&quot;&gt;         &lt;b style=&quot;font-size: 14px;&quot;&gt;ACTS Food Assitance&lt;/b&gt;&lt;br&gt;         &lt;i style=&quot;color: #555;&quot;&gt;Food&lt;/i&gt;&lt;br&gt;&lt;br&gt;         &lt;b&gt;Services Provided:&lt;/b&gt; Monthly food pick-up on walk-in basis. New client enrollment Wednesdays 10am-1pm.&lt;br&gt;         &lt;b&gt;Address:&lt;/b&gt; 3901 ACTS Ln, Dumfries, VA 22026&lt;br&gt;         &lt;b&gt;Email:&lt;/b&gt; info@actspwc.org&lt;br&gt;         &lt;b&gt;Phone:&lt;/b&gt; (703) 441-8606&lt;br&gt;         &lt;b&gt;Website:&lt;/b&gt; &lt;a href=&quot;https://www.actspwc.org/services/food-assistance&quot; target=&quot;_blank&quot;&gt;Visit&lt;/a&gt;     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_6a70f434041f15083ac9923ab3a00205.setContent(html_150d6f0ae28991ff3d17eaf42948ade5);
#
#
#
#         marker_7f4352d1a52c3743103dd81c8554c6ef.bindPopup(popup_6a70f434041f15083ac9923ab3a00205)
#         ;
#
#
#
#
#             var marker_ecc59e84655dfd7b6758ebd8261d30f4 = L.marker(
#                 [38.7701015, -77.4906759],
#                 {}
#             ).addTo(marker_cluster_72b128883751dff62d45e841b9243f9a);
#
#
#             var icon_3750a1387b311cfa65b674222155045e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ecc59e84655dfd7b6758ebd8261d30f4.setIcon(icon_3750a1387b311cfa65b674222155045e);
#
#
#         var popup_183edb009f962c28e9611c1b64b5acb2 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_1d66851e7ecdb238253afa8a874b41f2 = $(`&lt;div id=&quot;html_1d66851e7ecdb238253afa8a874b41f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&quot;font-family: Arial; font-size: 13px;&quot;&gt;         &lt;b style=&quot;font-size: 14px;&quot;&gt;Creating Foundations for Hope&lt;/b&gt;&lt;br&gt;         &lt;i style=&quot;color: #555;&quot;&gt;Food&lt;/i&gt;&lt;br&gt;&lt;br&gt;         &lt;b&gt;Services Provided:&lt;/b&gt; Food distributed at East End Mobile Home Park&lt;br&gt;         &lt;b&gt;Address:&lt;/b&gt; 8565 Sudley Rd, Manassas, VA 20110&lt;br&gt;         &lt;b&gt;Email:&lt;/b&gt; info@cfhva.org&lt;br&gt;         &lt;b&gt;Phone:&lt;/b&gt; (703) 221-4510, ext 2001&lt;br&gt;         &lt;b&gt;Website:&lt;/b&gt; &lt;a href=&quot;https://cfhva.org/&quot; target=&quot;_bla

# %%
m.save("templates/map.html")

# %%
import folium

# Define custom icons for different resource types
ICON_MAP = {
    "Food": ("green", "glyphicon-cutlery"),  # 🍏 Food icon
    "Clothing": ("purple", "glyphicon-shopping-cart"),  # 👕 Clothing icon
    "Medical and Healthcare": ("red", "glyphicon-plus")  # 🏥 Medical icon
}

# Sample data (Replace with your actual data source)
resources = [
    {
        'Name': 'ACTS Food Assistance',
        'Type': 'Food',
        'Services Provided': 'Monthly food pick-up on walk-in basis. New client enrollment Wednesdays 10am-1pm.',
        'Address': '3901 ACTS Ln, Dumfries, VA 22026',
        'Latitude': 38.5632239,
        'Longitude': -77.3316961,
        'Contact': None,
        'Website': 'https://www.actspwc.org/services/food-assistance'
    },
    {
        'Name': 'House of Mercy Thrift Store',
        'Type': 'Clothing',
        'Services Provided': 'Clothes once a month for each registered family member. Once a year special occasion for teens.',
        'Address': '8170 Flannery Court, Manassas, VA 20109',
        'Latitude': 38.7816723,
        'Longitude': -77.5604866,
        'Contact': '(703) 659-1636, appointment only',
        'Website': 'https://houseofmercyva.org/programs/food-pantry-client-services/'
    },
    {
        'Name': 'Greater Prince William Community Health Center',
        'Type': 'Medical and Healthcare',
        'Services Provided': 'Sick Visits, Wellness Visits, Chronic Disease Management, Prenatal, Immunization, Lab Services, Pharmacy Assistance, Mental Health, Dental Care.',
        'Address': '4379 Ridgewood, Centre Dr., #102, Woodbridge, VA 22192',
        'Latitude': 38.673549,
        'Longitude': -77.3432914,
        'Contact': '(703)- 680-7950',
        'Website': None  # This is the problematic case
    }
]

# Create map centered around the county
m = folium.Map(location=[38.5, -77.5], zoom_start=10)

# Add markers for each resource
for res in resources:
    # Get icon color and symbol based on type, defaulting to blue marker
    icon_color, icon_symbol = ICON_MAP.get(res["Type"], ("blue", "glyphicon-info-sign"))

    # Ensure website is a string and handle None values
    website_link = f'<a href="{res["Website"]}" target="_blank">Visit</a>' if isinstance(res["Website"], str) and res["Website"] else "N/A"

    # Format popup content with styled HTML
    popup_content = f"""
    <div style="font-family: Arial; font-size: 13px;">
        <b style="font-size: 14px;">{res['Name']}</b><br>
        <i style="color: #555;">{res['Type']}</i><br><br>
        <b>Services Provided:</b> {res['Services Provided']}<br>
        <b>Address:</b> {res['Address']}<br>
        <b>Contact:</b> {res['Contact'] if res['Contact'] else 'N/A'}<br>
        <b>Website:</b> {website_link}
    </div>
    """

    folium.Marker(
        location=[res["Latitude"], res["Longitude"]],
        popup=folium.Popup(popup_content, max_width=300),
        icon=folium.Icon(color=icon_color, icon=icon_symbol)
    ).add_to(m)

# Save the map to an HTML file
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d665578b013b488cef1485de3d8047db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d665578b013b488cef1485de3d8047db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d665578b013b488cef1485de3d8047db = L.map(
#                 &quot;map_d665578b013b488cef1485de3d8047db&quot;,
#                 {
#                     center: [38.5, -77.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a38381abb41a3b0ea1b4d831647ab46e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a38381abb41a3b0ea1b4d831647ab46e.addTo(map_d665578b013b488cef1485de3d8047db);
#
#
#             var marker_8d8596aa55d8a1f2fd33d22979c41cda = L.marker(
#                 [38.5632239, -77.3316961],
#                 {}
#             ).addTo(map_d665578b013b488cef1485de3d8047db);
#
#
#             var icon_9eec38ee8d29cca25b783e468a9f5dee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8d8596aa55d8a1f2fd33d22979c41cda.setIcon(icon_9eec38ee8d29cca25b783e468a9f5dee);
#
#
#         var popup_a9b1f632de5dc787510a32f03faf9d46 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_5836f2ad831240154fc723e242315218 = $(`&lt;div id=&quot;html_5836f2ad831240154fc723e242315218&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&quot;font-family: Arial; font-size: 13px;&quot;&gt;         &lt;b style=&quot;font-size: 14px;&quot;&gt;ACTS Food Assistance&lt;/b&gt;&lt;br&gt;         &lt;i style=&quot;color: #555;&quot;&gt;Food&lt;/i&gt;&lt;br&gt;&lt;br&gt;         &lt;b&gt;Services Provided:&lt;/b&gt; Monthly food pick-up on walk-in basis. New client enrollment Wednesdays 10am-1pm.&lt;br&gt;         &lt;b&gt;Address:&lt;/b&gt; 3901 ACTS Ln, Dumfries, VA 22026&lt;br&gt;         &lt;b&gt;Contact:&lt;/b&gt; N/A&lt;br&gt;         &lt;b&gt;Website:&lt;/b&gt; &lt;a href=&quot;https://www.actspwc.org/services/food-assistance&quot; target=&quot;_blank&quot;&gt;Visit&lt;/a&gt;     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_a9b1f632de5dc787510a32f03faf9d46.setContent(html_5836f2ad831240154fc723e242315218);
#
#
#
#         marker_8d8596aa55d8a1f2fd33d22979c41cda.bindPopup(popup_a9b1f632de5dc787510a32f03faf9d46)
#         ;
#
#
#
#
#             var marker_0c1e706b6c1ff8ba81470ff7412032bc = L.marker(
#                 [38.7816723, -77.5604866],
#                 {}
#             ).addTo(map_d665578b013b488cef1485de3d8047db);
#
#
#             var icon_bb07e7a5761b815c18cdda489bcae39e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-shopping-cart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0c1e706b6c1ff8ba81470ff7412032bc.setIcon(icon_bb07e7a5761b815c18cdda489bcae39e);
#
#
#         var popup_4bcbcac46c5c0131c646b0b092ba8a72 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_3743f27f2fd278e0551c3b64af0048eb = $(`&lt;div id=&quot;html_3743f27f2fd278e0551c3b64af0048eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div style=&quot;font-family: Arial; font-size: 13px;&quot;&gt;         &lt;b style=&quot;font-size: 14px;&quot;&gt;House of Mercy Thrift Store&lt;/b&gt;&lt;br&gt;         &lt;i style=&quot;color: #555;&quot;&gt;Clothing&lt;/i&gt;&lt;br&gt;&lt;br&gt;         &lt;b&gt;Services Provided:&lt;/b&gt; Clothes once a month for each registered family member. Once a year special occasion for teens.&lt;br&gt;         &lt;b&gt;Address:&lt;/b&gt; 8170 Flannery Court, Manassas, VA 20109&lt;br&gt;         &lt;b&gt;Contact:&lt;/b&gt; (703) 659-1636, appointment only&lt;br&gt;         &lt;b&gt;Website:&lt;/b&gt; &lt;a href=&quot;https://houseofmercyva.org/programs/food-pantry-client-services/&quot; target=&quot;_blank&quot;&gt;Visit&lt;/a&gt;     &lt;/div&gt;     &lt;/div&gt;`)[0];
#                 popup_4bcbcac46c5c0131c646b0b092ba8a72.setContent(html_3743f27f2fd278e0551c3b64af0048eb);
#
#
#
#         marker_0c1e706b6c1ff8ba81470ff7412032bc.bindPopup(popup_4bcbcac46c5c0131c646b0b092ba8a72)
#         ;
#
#
#
#
#             var marker_629ea4de97e44b197379195034816461 = L.marker(
#                 [38.673549, -77.3432914],
#                 {}
#             ).addTo(map_d665578b013b488cef1485de3d8047db);
#
#
#             var icon_c6d14884a0a129dbd26d3fcf4599f3
